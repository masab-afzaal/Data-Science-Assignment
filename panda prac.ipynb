# %%
import pandas as pd

# %%
used_cars = pd.read_csv("../cars.csv")

# %%
used_cars.head()
# Out:
#    Car_ID    Brand    Model  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0       1   Toyota  Corolla  2018              50000    Petrol       Manual
# 1       2    Honda    Civic  2019              40000    Petrol    Automatic
# 2       3     Ford  Mustang  2017              20000    Petrol    Automatic
# 3       4   Maruti    Swift  2020              30000    Diesel       Manual
# 4       5  Hyundai   Sonata  2016              60000    Diesel    Automatic
#
#   Owner_Type  Mileage  Engine  Power  Seats    Price
# 0      First       15    1498    108      5   800000
# 1     Second       17    1597    140      5  1000000
# 2      First       10    4951    395      4  2500000
# 3      Third       23    1248     74      5   600000
# 4     Second       18    1999    194      5   850000

# %%
used_cars
# Out:
#     Car_ID     Brand          Model  Year  Kilometers_Driven Fuel_Type  \
# 0        1    Toyota        Corolla  2018              50000    Petrol
# 1        2     Honda          Civic  2019              40000    Petrol
# 2        3      Ford        Mustang  2017              20000    Petrol
# 3        4    Maruti          Swift  2020              30000    Diesel
# 4        5   Hyundai         Sonata  2016              60000    Diesel
# ..     ...       ...            ...   ...                ...       ...
# 95      96  Mercedes        C-Class  2019              22000    Diesel
# 96      97    Toyota  Innova Crysta  2017              38000    Diesel
# 97      98      Ford       EcoSport  2018              26000    Petrol
# 98      99   Hyundai          Verna  2019              24000    Petrol
# 99     100      Tata         Altroz  2020              18000    Petrol
#
#    Transmission Owner_Type  Mileage  Engine  Power  Seats    Price
# ...

# %%
used_cars.dtypes
# Out:
# Car_ID                int64
# Brand                object
# Model                object
# Year                  int64
# Kilometers_Driven     int64
# Fuel_Type            object
# Transmission         object
# Owner_Type           object
# Mileage               int64
# Engine                int64
# Power                 int64
# Seats                 int64
# Price                 int64
# dtype: object

# %%
used_cars.columns
# Out:
# Index(['Car_ID', 'Brand', 'Model', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'Price'],
#       dtype='object')

# %%
used_cars.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
used_cars.Brand
# Out:
# 0       Toyota
# 1        Honda
# 2         Ford
# 3       Maruti
# 4      Hyundai
#         ...
# 95    Mercedes
# 96      Toyota
# 97        Ford
# 98     Hyundai
# 99        Tata
# Name: Brand, Length: 100, dtype: object

# %%
used_cars[["Brand","Power",  "Price"]]
# Out:
#        Brand  Power    Price
# 0     Toyota    108   800000
# 1      Honda    140  1000000
# 2       Ford    395  2500000
# 3     Maruti     74   600000
# 4    Hyundai    194   850000
# ..       ...    ...      ...
# 95  Mercedes    191  2900000
# 96    Toyota    171  1400000
# 97      Ford    121   750000
# 98   Hyundai    113   850000
# 99      Tata     85   600000
#
# [100 rows x 3 columns]

# %%
used_cars.loc[1:6,"Brand"]
# Out:
# 1       Honda
# 2        Ford
# 3      Maruti
# 4     Hyundai
# 5        Tata
# 6    Mahindra
# Name: Brand, dtype: object

# %%
name
# Out:
# 1       Honda
# 2        Ford
# 3      Maruti
# 4     Hyundai
# 5        Tata
# 6    Mahindra
# Name: Brand, dtype: object

# %%
used_cars.Brand[[2,5,44]]
# Out:
# 2      Ford
# 5      Tata
# 44    Honda
# Name: Brand, dtype: object

# %%
name = used_cars[["Brand", "Price"]]

# %%
name
# Out:
#        Brand    Price
# 0     Toyota   800000
# 1      Honda  1000000
# 2       Ford  2500000
# 3     Maruti   600000
# 4    Hyundai   850000
# ..       ...      ...
# 95  Mercedes  2900000
# 96    Toyota  1400000
# 97      Ford   750000
# 98   Hyundai   850000
# 99      Tata   600000
#
# [100 rows x 2 columns]

# %%
name.Brand
# Out:
# 0       Toyota
# 1        Honda
# 2         Ford
# 3       Maruti
# 4      Hyundai
#         ...
# 95    Mercedes
# 96      Toyota
# 97        Ford
# 98     Hyundai
# 99        Tata
# Name: Brand, Length: 100, dtype: object

# %%
name.Brand[12]
# Out:
# 'Hyundai'

# %%
name.Price.max()
# Out:
# 4000000

# %%
name.describe()
# Out:
#               Price
# count  1.000000e+02
# mean   1.574000e+06
# std    1.000265e+06
# min    4.500000e+05
# 25%    7.000000e+05
# 50%    1.300000e+06
# 75%    2.500000e+06
# max    4.000000e+06

# %%
used_cars.Brand.value_counts()
# Out:
# Brand
# Ford          11
# Hyundai       11
# Tata          11
# Toyota        10
# Volkswagen    10
# Audi          10
# BMW           10
# Mercedes      10
# Honda          6
# Maruti         6
# Mahindra       5
# Name: count, dtype: int64

# %%
used_cars.columns
# Out:
# Index(['Car_ID', 'Brand', 'Model', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'Price'],
#       dtype='object')

# %%
used_cars.Fuel_Type.unique()
# Out:
# array(['Petrol', 'Diesel'], dtype=object)

# %%
used_cars.sort_values(by = "Price",inplace = True, ascending = False)
used_cars.head()
# Out:
#     Car_ID     Brand     Model  Year  Kilometers_Driven Fuel_Type  \
# 38      39  Mercedes       GLE  2018              26000    Petrol
# 76      77  Mercedes       GLE  2018              26000    Petrol
# 37      38       BMW  7 Series  2019              22000    Diesel
# 75      76       BMW  7 Series  2019              22000    Diesel
# 85      86       BMW        X5  2018              28000    Petrol
#
#    Transmission Owner_Type  Mileage  Engine  Power  Seats    Price
# 38    Automatic     Second       12    2996    362      5  4000000
# 76    Automatic     Second       12    2996    362      5  4000000
# 37    Automatic      First       15    2993    261      5  3500000
# 75    Automatic      First       15    2993    261      5  3500000
# 85    Automatic     Second       14    2998    335      5  3200000

# %%
used_cars.columns
# Out:
# Index(['Car_ID', 'Brand', 'Model', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'Price'],
#       dtype='object')

# %%
used_cars["new_column"]=1

# %%
import pandas as pd

# %%
used_cars = pd.read_csv("../cars.csv")

# %%
used_cars.columns
# Out:
# Index(['Car_ID', 'Brand', 'Model', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'Price', 'new_column'],
#       dtype='object')

# %%
del used_cars['new_column']

# %%
used_cars.columns
# Out:
# Index(['Car_ID', 'Brand', 'Model', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'Price'],
#       dtype='object')

# %%
used_cars.head()
# Out:
#    Car_ID    Brand    Model  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0       1   Toyota  Corolla  2018              50000    Petrol       Manual
# 1       2    Honda    Civic  2019              40000    Petrol    Automatic
# 2       3     Ford  Mustang  2017              20000    Petrol    Automatic
# 3       4   Maruti    Swift  2020              30000    Diesel       Manual
# 4       5  Hyundai   Sonata  2016              60000    Diesel    Automatic
#
#   Owner_Type  Mileage  Engine  Power  Seats    Price
# 0      First       15    1498    108      5   800000
# 1     Second       17    1597    140      5  1000000
# 2      First       10    4951    395      4  2500000
# 3      Third       23    1248     74      5   600000
# 4     Second       18    1999    194      5   850000

# %%
used_cars.drop([2,3], axis=0, inplace = False)
# Out:
#     Car_ID     Brand          Model  Year  Kilometers_Driven Fuel_Type  \
# 0        1    Toyota        Corolla  2018              50000    Petrol
# 1        2     Honda          Civic  2019              40000    Petrol
# 4        5   Hyundai         Sonata  2016              60000    Diesel
# 5        6      Tata          Nexon  2019              35000    Petrol
# 6        7  Mahindra        Scorpio  2018              45000    Diesel
# ..     ...       ...            ...   ...                ...       ...
# 95      96  Mercedes        C-Class  2019              22000    Diesel
# 96      97    Toyota  Innova Crysta  2017              38000    Diesel
# 97      98      Ford       EcoSport  2018              26000    Petrol
# 98      99   Hyundai          Verna  2019              24000    Petrol
# 99     100      Tata         Altroz  2020              18000    Petrol
#
#    Transmission Owner_Type  Mileage  Engine  Power  Seats    Price
# ...

# %%
used_cars.head()
# Out:
#    Car_ID    Brand    Model  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0       1   Toyota  Corolla  2018              50000    Petrol       Manual
# 1       2    Honda    Civic  2019              40000    Petrol    Automatic
# 2       3     Ford  Mustang  2017              20000    Petrol    Automatic
# 3       4   Maruti    Swift  2020              30000    Diesel       Manual
# 4       5  Hyundai   Sonata  2016              60000    Diesel    Automatic
#
#   Owner_Type  Mileage  Engine  Power  Seats    Price
# 0      First       15    1498    108      5   800000
# 1     Second       17    1597    140      5  1000000
# 2      First       10    4951    395      4  2500000
# 3      Third       23    1248     74      5   600000
# 4     Second       18    1999    194      5   850000

# %%
used_cars.rename(columns = { "Brand" : "Name"}, inplace = False)
# Out:
#     Car_ID      Name          Model  Year  Kilometers_Driven Fuel_Type  \
# 0        1    Toyota        Corolla  2018              50000    Petrol
# 1        2     Honda          Civic  2019              40000    Petrol
# 2        3      Ford        Mustang  2017              20000    Petrol
# 3        4    Maruti          Swift  2020              30000    Diesel
# 4        5   Hyundai         Sonata  2016              60000    Diesel
# ..     ...       ...            ...   ...                ...       ...
# 95      96  Mercedes        C-Class  2019              22000    Diesel
# 96      97    Toyota  Innova Crysta  2017              38000    Diesel
# 97      98      Ford       EcoSport  2018              26000    Petrol
# 98      99   Hyundai          Verna  2019              24000    Petrol
# 99     100      Tata         Altroz  2020              18000    Petrol
#
#    Transmission Owner_Type  Mileage  Engine  Power  Seats    Price
# ...

# %%
used_cars.head()
# Out:
#    Car_ID    Brand    Model  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0       1   Toyota  Corolla  2018              50000    Petrol       Manual
# 1       2    Honda    Civic  2019              40000    Petrol    Automatic
# 2       3     Ford  Mustang  2017              20000    Petrol    Automatic
# 3       4   Maruti    Swift  2020              30000    Diesel       Manual
# 4       5  Hyundai   Sonata  2016              60000    Diesel    Automatic
#
#   Owner_Type  Mileage  Engine  Power  Seats    Price
# 0      First       15    1498    108      5   800000
# 1     Second       17    1597    140      5  1000000
# 2      First       10    4951    395      4  2500000
# 3      Third       23    1248     74      5   600000
# 4     Second       18    1999    194      5   850000

# %%
used_cars.isnull()
# Out:
#     Car_ID  Brand  Model   Year  Kilometers_Driven  Fuel_Type  Transmission  \
# 0    False  False  False  False              False      False         False
# 1    False  False  False  False              False      False         False
# 2    False  False  False  False              False      False         False
# 3    False  False  False  False              False      False         False
# 4    False  False  False  False              False      False         False
# ..     ...    ...    ...    ...                ...        ...           ...
# 95   False  False  False  False              False      False         False
# 96   False  False  False  False              False      False         False
# 97   False  False  False  False              False      False         False
# 98   False  False  False  False              False      False         False
# 99   False  False  False  False              False      False         False
#
#     Owner_Type  Mileage  Engine  Power  Seats  Price
# ...

# %%
import pandas as pd
used_cars = pd.read_csv("../cars.csv")

# %%
used_cars.head()
# Out:
#    Car_ID    Brand    Model  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0       1   Toyota  Corolla  2018              50000    Petrol       Manual
# 1       2    Honda    Civic  2019              40000    Petrol    Automatic
# 2       3     Ford  Mustang  2017              20000    Petrol    Automatic
# 3       4   Maruti    Swift  2020              30000    Diesel       Manual
# 4       5  Hyundai   Sonata  2016              60000    Diesel    Automatic
#
#   Owner_Type  Mileage  Engine  Power  Seats    Price
# 0      First       15    1498    108      5   800000
# 1     Second       17    1597    140      5  1000000
# 2      First       10    4951    395      4  2500000
# 3      Third       23    1248     74      5   600000
# 4     Second       18    1999    194      5   850000
